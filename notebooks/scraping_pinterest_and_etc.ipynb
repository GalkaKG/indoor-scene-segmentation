# %%
import requests
from bs4 import BeautifulSoup
import os

def scrape_images(url, folder, max_images=150):
    os.makedirs(folder, exist_ok=True)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all divs with the specific class for photo cards
    photo_cards = soup.find_all('div', class_='hz-photo-card hz-track-me')
    
    count = 0
    for card in photo_cards:
        # Find the <a> tag inside the div with class 'hz-photo-card__ratio-box'
        a_tag = card.find('a', class_='hz-photo-card__ratio-box')
        if a_tag:
            # Find the <img> tag inside the <a> tag
            img_tag = a_tag.find('img', class_='hz-photo-card__img')
            if img_tag:
                # Extract the image URL from 'src' or 'srcset' attribute
                src = img_tag.get('src')
                if src and count < max_images:
                    try:
                        # Download the image
                        img_data = requests.get(src).content
                        with open(f"{folder}/image_{count}.jpg", 'wb') as f:
                            f.write(img_data)
                        count += 1
                    except Exception as e:
                        print(f"Could not download {src}: {e}")

    print(f"Downloaded {count} images to {folder}")


scrape_images('https://www.houzz.com/photos/modern-kitchen-ideas-phbr1-bp~t_709~s_2105', 'data/raw/kitchen/modern')
# Out:
# Downloaded 19 images to data/raw/kitchen/modern

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import StaleElementReferenceException
import time
import requests
import os

def scrape_pinterest_images(url, folder, name_img, max_images=300):
    os.makedirs(folder, exist_ok=True)
    
    # Set up Selenium WebDriver
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")  # Run in headless mode (no browser window)
    
    # Specify the path to the ChromeDriver executable
    service = Service('C:/Program Files/chromedriver-win64/chromedriver.exe')  
    
    driver = webdriver.Chrome(service=service, options=options)
    
    driver.get(url)
    time.sleep(3)  # Wait for the page to load fully

    images = set()
    count = 0
    
    while count < max_images:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)  # Wait for more images to load

        try:
            # Find the specific <div> elements
            div_elements = driver.find_elements(By.CSS_SELECTOR, "div[data-test-id='deeplink-wrapper'] img")
        except Exception as e:
            print(f"Error while fetching images: {e}")
            continue

        for div in div_elements:
            try:
                # Get the src attribute from the img inside the div
                img_url = div.get_attribute('src')
                if img_url and img_url not in images:
                    images.add(img_url)
                    try:
                        img_data = requests.get(img_url).content
                        with open(f"{folder}/{name_img}_{count}.jpg", 'wb') as f:
                            f.write(img_data)
                        print(f"Downloaded image {count + 1}: {img_url}")
                        count += 1
                        if count >= max_images:
                            break
                    except Exception as e:
                        print(f"Could not download {img_url}: {e}")
            except StaleElementReferenceException:
                print("Encountered stale element. Skipping this image.")
                continue

    driver.quit()
    print(f"Downloaded {count} images to {folder}")

scrape_pinterest_images(
    'https://za.pinterest.com/search/pins/?q=industrial%20bedroom%20design&rs=typed',
    'data/raw/bedroom/industrial',
    'bedroom_industrial'
)

# scrape_pinterest_images(
#     'https://za.pinterest.com/search/pins/?q=boho%20toilet%20design&rs=typed',
#     'data/raw/bathroom/boho',
#     'bathroom_boho'
# )

# scrape_pinterest_images(
#     'https://za.pinterest.com/search/pins/?q=scandinavian%20toilet%20design&rs=typed',
#     'data/raw/bathroom/scandinavian',
#     'bathroom_scandinavian'
# )

# scrape_pinterest_images(
#     'https://za.pinterest.com/search/pins/?q=minimalist%20toilet%20design&rs=typed',
#     'data/raw/bathroom/minimalist',
#     'bathroom_minimalist'
# )

# scrape_pinterest_images(
#     'https://za.pinterest.com/search/pins/?q=modern%20toilet%20design&rs=typed',
#     'data/raw/bathroom/modern',
#     'bathroom_modern'
# )
# Out:
# Downloaded image 1: https://i.pinimg.com/236x/2c/b8/a9/2cb8a90369a2b44963fe3075d5f1d3d6.jpg
# Downloaded image 2: https://i.pinimg.com/236x/2d/7b/16/2d7b16661d59def110874238dc4861fc.jpg
# Downloaded image 3: https://i.pinimg.com/236x/84/ea/7e/84ea7e4c6d82dbbbdf62ce012a8c1b4f.jpg
# Downloaded image 4: https://i.pinimg.com/236x/8c/f1/18/8cf11801befeb0b1478480b12fe24742.jpg
# Downloaded image 5: https://i.pinimg.com/236x/80/34/76/80347678401225bb3da9f751528a1b2d.jpg
# Downloaded image 6: https://i.pinimg.com/236x/b7/cf/ba/b7cfba821514f33842143cb52751ba48.jpg
# Downloaded image 7: https://i.pinimg.com/236x/51/86/3c/51863c06a06b9c21395ab580a3feb2c4.jpg
# Downloaded image 8: https://i.pinimg.com/236x/63/a4/c8/63a4c89b67f6cfb9b236854e805f4aa9.jpg
# Downloaded image 9: https://i.pinimg.com/236x/85/58/b4/8558b411dadcffc543a4d8ab4297680a.jpg
# Downloaded image 10: https://i.pinimg.com/236x/d1/ab/05/d1ab055c70e42a79a179b9b5b1ae3696.jpg
# Downloaded image 11: https://i.pinimg.com/236x/93/6c/c9/936cc929c53102c561fbe7a3a5222aab.jpg
# Downloaded image 12: https://i.pinimg.com/236x/35/9b/df/359bdf7dc8ac067cbe1b4b259dd49e3c.jpg
# Downloaded image 13: https://i.pinimg.com/236x/80/48/8e/80488e5d171c67b070d59b3549392a42.jpg
# Downloaded image 14: https://i.pinimg.com/236x/13/03/8b/13038b6d93fac0a6f1603d0b0e22cbfe.jpg
# Downloaded image 15: https://i.pinimg.com/236x/8a/3b/7e/8a3b7eb0a1e2cf1029c6d70d1a0def2e.jpg
# Encountered stale element. Skipping this image.
# Encountered stale element. Skipping this image.
# Downloaded image 16: https://i.pinimg.com/236x/77/b7/32/77b732d504ab7cf56e272a3f7138e4cd.jpg
# Downloaded image 17: https://i.pinimg.com/236x/97/ee/8b/97ee8b5111f7c72cb1a56ae679d94c7e.jpg
# Downloaded image 18: https://i.pinimg.com/236x/c1/33/6e/c1336e58992200bd858d31363229ad6f.jpg
# Downloaded image 19: https://i.pinimg.com/236x/39/e7/d0/39e7d0a0170b71aea6b864b1fb8d43ce.jpg
# Downloaded image 20: https://i.pinimg.com/236x/21/b3/87/21b387f6c29fe508b8972ddce8d2c03e.jpg
# Downloaded image 21: https://i.pinimg.com/236x/09/76/54/097654ee4cf037d553ebdbbc76d52fce.jpg
# Downloaded image 22: https://i.pinimg.com/236x/42/0c/d3/420cd312ac86c80edd75a0c0b6e89b2a.jpg
# Downloaded image 23: https://i.pinimg.com/236x/36/39/59/3639593b35a8b97161beffb482bafcf2.jpg
# Downloaded image 24: https://i.pinimg.com/236x/d2/6b/04/d26b04ade4d7aed210d0c9332f0bcc04.jpg
# Downloaded image 25: https://i.pinimg.com/236x/ed/27/53/ed2753014e65f1fdbb94a3fe0dcadd8a.jpg
# Downloaded image 26: https://i.pinimg.com/236x/39/00/e7/3900e770441e810db2fac0cbb330dd1d.jpg
# Downloaded image 27: https://i.pinimg.com/236x/b4/ab/d1/b4abd11cab51880e94e744fa224889ee.jpg
# Downloaded image 28: https://i.pinimg.com/236x/dc/83/1c/dc831c1b0845aaed2a0697ecd6eb13a5.jpg
# Downloaded image 29: https://i.pinimg.com/236x/d8/c7/d3/d8c7d33b095ac52ea5aa7a711fc0263f.jpg
# Encountered stale element. Skipping this image.
# Encountered stale element. Skipping this image.
# Downloaded image 30: https://i.pinimg.com/236x/28/2d/83/282d8378c4b0aaa04d09834a84bdae90.jpg
# Downloaded image 31: https://i.pinimg.com/236x/82/63/cc/8263cc38b7cf259a89f725591c75c629.jpg
# Downloaded image 32: https://i.pinimg.com/236x/6a/b8/d1/6ab8d1779193da3c5eddbc6a6734b5f0.jpg
# Downloaded image 33: https://i.pinimg.com/236x/2b/76/7e/2b767e6b4c3c46b31ab3ff0dcf588784.jpg
# Downloaded image 34: https://i.pinimg.com/236x/34/e9/88/34e9881fe65408258c81bd61e04ec2dc.jpg
# Downloaded image 35: https://i.pinimg.com/236x/84/de/b6/84deb6ba5bab0b3018d81b5a7856c0ce.jpg
# Downloaded image 36: https://i.pinimg.com/236x/4b/c6/0d/4bc60db2055374486648a10aada0ba8f.jpg
# Downloaded image 37: https://i.pinimg.com/236x/ad/f3/03/adf303213e9ee390d832492ca6a1a8f1.jpg
# Downloaded image 38: https://i.pinimg.com/236x/b2/40/c2/b240c204f39b6c5c245560d85a7d7021.jpg
# Downloaded image 39: https://i.pinimg.com/236x/f0/76/84/f07684a634321e0cd47c3dec91426d09.jpg
# Downloaded image 40: https://i.pinimg.com/236x/26/ec/cb/26eccbce503ac9e743a734b862771553.jpg
# Downloaded image 41: https://i.pinimg.com/236x/81/99/18/8199187f253d98e16129fce200b3198c.jpg
# Downloaded image 42: https://i.pinimg.com/236x/ef/38/3f/ef383fc5184570c0e41b58ab51c13ca5.jpg
# Downloaded image 43: https://i.pinimg.com/236x/f9/dc/7b/f9dc7b166c665a0f8f6c575c20de59ee.jpg
# Downloaded image 44: https://i.pinimg.com/236x/d1/61/5b/d1615ba2c27a47d82411ac72b3b7d920.jpg
# Downloaded image 45: https://i.pinimg.com/236x/e9/ea/24/e9ea24eb95266b9af5ed6c32641d5c3e.jpg
# Downloaded image 46: https://i.pinimg.com/236x/60/51/79/60517917bf504844403403f5cf082dad.jpg
# Downloaded image 47: https://i.pinimg.com/236x/c0/15/82/c01582721a81e685539649d3d3f38949.jpg
# Downloaded image 48: https://i.pinimg.com/236x/0c/bf/d0/0cbfd0398df782878b30f47d1c54e48d.jpg
# Downloaded image 49: https://i.pinimg.com/236x/7d/6f/6e/7d6f6e97396e3f79b94281d470749d2b.jpg
# Downloaded image 50: https://i.pinimg.com/236x/ba/9a/86/ba9a86a6ced95fd1d871bbb8a0b1c21a.jpg
# Downloaded image 51: https://i.pinimg.com/236x/ef/ed/80/efed80ee035f69b796b6b2bd2e8394b9.jpg
# Downloaded image 52: https://i.pinimg.com/236x/d4/db/e9/d4dbe9b8be400d6225b7d05cfc68cdbe.jpg
# Downloaded image 53: https://i.pinimg.com/236x/f3/36/ac/f336acc126ab4d0ac0db3dbab8788fda.jpg
# Downloaded image 54: https://i.pinimg.com/236x/ee/d3/1e/eed31eabce24471581ad540247c56d22.jpg
# Downloaded image 55: https://i.pinimg.com/236x/f4/de/50/f4de500479f50367b7077716637876e7.jpg
# Downloaded image 56: https://i.pinimg.com/236x/0b/d2/b4/0bd2b497bfefd65f599f0bf6558d49eb.jpg
# Downloaded image 57: https://i.pinimg.com/236x/4e/fd/a1/4efda1099f3dd687e48c584aa367b93a.jpg
# Downloaded image 58: https://i.pinimg.com/236x/e3/a5/24/e3a5243f599b179d53d770ec7a6222a4.jpg
# Downloaded image 59: https://i.pinimg.com/236x/a4/d2/2f/a4d22f5b2371b5d3414e9a56e69464a6.jpg
# Downloaded image 60: https://i.pinimg.com/236x/ab/04/c4/ab04c40085a556665ccf135b4c637917.jpg
# Downloaded image 61: https://i.pinimg.com/236x/bb/07/47/bb0747a3b613e6e9efc8e9d6ddea468e.jpg
# Downloaded image 62: https://i.pinimg.com/236x/32/47/1e/32471e50c87c2774b3069ec18ff04e57.jpg
# Downloaded image 63: https://i.pinimg.com/236x/3f/22/c5/3f22c533fd6e2a618708b79363a95ecd.jpg
# Downloaded image 64: https://i.pinimg.com/236x/15/92/2d/15922dc488af3796f0d6ef1005a013e8.jpg
# Downloaded image 65: https://i.pinimg.com/236x/a9/1e/00/a91e00c672d752da8f586e223f968e0a.jpg
# Downloaded image 66: https://i.pinimg.com/236x/d8/29/7c/d8297c781d0529926343f431454cb66c.jpg
# Downloaded image 67: https://i.pinimg.com/236x/14/1d/bd/141dbd0052057cc266745b1e6d652a96.jpg
# Downloaded image 68: https://i.pinimg.com/236x/0b/1e/e5/0b1ee59e30d3c4f62bfe4fbff3fb786e.jpg
# Downloaded image 69: https://i.pinimg.com/236x/b3/5c/ce/b35cce3972d55632aa8bf23f23a46903.jpg
# Downloaded image 70: https://i.pinimg.com/236x/72/10/6e/72106e16c871342abfa0be4638028a36.jpg
# Downloaded image 71: https://i.pinimg.com/236x/3a/44/b8/3a44b81b0fffe88ee57e7c55d79ac0a7.jpg
# Downloaded image 72: https://i.pinimg.com/236x/1f/40/0a/1f400ad44a441cd3940bf02e597e3308.jpg
# Downloaded image 73: https://i.pinimg.com/236x/63/2a/ea/632aea23af68afb2d30e146e2371e8b3.jpg
# Downloaded image 74: https://i.pinimg.com/236x/cb/bc/a7/cbbca77bee01ae30143d29973f4f14c8.jpg
# Downloaded image 75: https://i.pinimg.com/236x/d1/5e/0f/d15e0faf75a4fe9f5edc7d2ae2b0c98f.jpg
# Downloaded image 76: https://i.pinimg.com/236x/03/f0/94/03f09450700a93a6a71514878c129851.jpg
# Downloaded image 77: https://i.pinimg.com/236x/82/98/92/8298927f738bb4c8c8048b5f80bdbc0b.jpg
# Downloaded image 78: https://i.pinimg.com/236x/68/a0/87/68a0870714c3463b65ba5673ec99f439.jpg
# Downloaded image 79: https://i.pinimg.com/236x/11/77/95/117795fc6a88674ec7cccd357478c314.jpg
# Downloaded image 80: https://i.pinimg.com/236x/c0/05/6f/c0056fb6db1eaba1cd6cc5873f0dc949.jpg
# Downloaded image 81: https://i.pinimg.com/236x/17/4f/55/174f550f7b34b42611e1fd814b01766f.jpg
# Downloaded image 82: https://i.pinimg.com/236x/76/56/8c/76568c01cc1fb7f86b9f5c5ca89c9d69.jpg
# Downloaded image 83: https://i.pinimg.com/236x/7f/a6/f2/7fa6f23993b5c78d8a4c3c987c159c9e.jpg
# Downloaded image 84: https://i.pinimg.com/236x/c0/cf/47/c0cf47a626f8da5222d9c5970b405f53.jpg
# Downloaded image 85: https://i.pinimg.com/236x/0c/87/a5/0c87a52cf413b2e06ffc2fb6fe66034a.jpg
# Downloaded image 86: https://i.pinimg.com/236x/79/a2/12/79a212ee241b5855d89255a7dc60cde4.jpg
# Downloaded image 87: https://i.pinimg.com/236x/4d/34/dc/4d34dcff788f17c9b78b2b786a0abd15.jpg
# Downloaded image 88: https://i.pinimg.com/236x/23/9e/2f/239e2fd0fc173c869c31368674bacccc.jpg
# Downloaded image 89: https://i.pinimg.com/236x/c3/a6/46/c3a646e0dd823f09f6c40e5738a07d50.jpg
# Downloaded image 90: https://i.pinimg.com/236x/eb/ed/23/ebed23f3400a15d79c738315b45fce52.jpg
# Downloaded image 91: https://i.pinimg.com/236x/21/91/ab/2191ab25732ddd8fa2b8cce0c1626af1.jpg
# Downloaded image 92: https://i.pinimg.com/236x/4b/a9/ca/4ba9cac5987ee77c086f8e42159f8a22.jpg
# Downloaded image 93: https://i.pinimg.com/236x/44/bd/31/44bd3155ef98f7c7426ddf46148060bf.jpg
# Downloaded image 94: https://i.pinimg.com/236x/fe/7f/23/fe7f232d5a187f353f9216b8382a5480.jpg
# Downloaded image 95: https://i.pinimg.com/236x/1f/7d/63/1f7d632a43396d8b78aa64e25a88afb5.jpg
# Downloaded image 96: https://i.pinimg.com/236x/2c/6c/aa/2c6caafbfd9f64637627ebd86bf80c4d.jpg
# Downloaded image 97: https://i.pinimg.com/236x/4a/39/0f/4a390f7dd3c4ea41e5c4f3bc8f5aae40.jpg
# Downloaded image 98: https://i.pinimg.com/236x/a9/1e/74/a91e74cbf592d901bc4cb90018737361.jpg
# Downloaded image 99: https://i.pinimg.com/236x/ba/63/dd/ba63dd3a9ce9b4ac5281cdaedb82029c.jpg
# Downloaded image 100: https://i.pinimg.com/236x/34/e4/ac/34e4acc9b0241ae46af3f465f7f8088b.jpg
# Downloaded image 101: https://i.pinimg.com/236x/e5/85/c1/e585c1c3ba6ba3d20bce3042219d7148.jpg
# Downloaded image 102: https://i.pinimg.com/236x/3c/2f/fb/3c2ffb0691b88f338755d60a1d852a8e.jpg
# Downloaded image 103: https://i.pinimg.com/236x/a3/f0/a6/a3f0a630375d76591996fde01ca641e2.jpg
# Downloaded image 104: https://i.pinimg.com/236x/91/3d/47/913d47a438172ac104c1ac23e637401b.jpg
# Downloaded image 105: https://i.pinimg.com/236x/a7/1c/02/a71c02293d1cdf97ef516b297365b107.jpg
# Downloaded image 106: https://i.pinimg.com/236x/a3/58/f3/a358f3885ca63ebc3100ee1bc3ddc511.jpg
# Downloaded image 107: https://i.pinimg.com/236x/66/ef/07/66ef07e686a56b6f2766e3fbfe093c83.jpg
# Downloaded image 108: https://i.pinimg.com/236x/8a/de/12/8ade1203e93e62c71f2de3c7e70a77c1.jpg
# Downloaded image 109: https://i.pinimg.com/236x/aa/dd/bc/aaddbccc79bbf99b23dc050900888942.jpg
# Downloaded image 110: https://i.pinimg.com/236x/e9/ee/16/e9ee164596d18ceb3ab381545e289f6d.jpg
# Downloaded image 111: https://i.pinimg.com/236x/9e/36/8e/9e368e863e823c395f302621a9371e0c.jpg
# Downloaded image 112: https://i.pinimg.com/236x/0b/b5/4c/0bb54cc1df79af1f0440cb86cb6ac553.jpg
# Downloaded image 113: https://i.pinimg.com/236x/4c/fd/03/4cfd03987d45dc4538b5869a9705a422.jpg
# Downloaded image 114: https://i.pinimg.com/236x/43/e8/4e/43e84e5c755bf74a712b51fdf740dd4a.jpg
# Downloaded image 115: https://i.pinimg.com/236x/ac/b8/48/acb8484e8e988e49aa4d274f0f3cbc98.jpg
# Downloaded image 116: https://i.pinimg.com/236x/9f/58/06/9f5806cf577df330c3da5e46478bda0f.jpg
# Downloaded image 117: https://i.pinimg.com/236x/43/a1/ce/43a1ce6e4c9e2d2a2b15894ce8c688f2.jpg
# Downloaded image 118: https://i.pinimg.com/236x/ef/b3/96/efb3960df93f46f8b363946bc347ac24.jpg
# Downloaded image 119: https://i.pinimg.com/236x/e2/38/77/e2387754c581422b7bd61c2d29d39c5c.jpg
# Downloaded image 120: https://i.pinimg.com/236x/6a/70/85/6a70853eae7de668126b52dcf99ebdab.jpg
# Downloaded image 121: https://i.pinimg.com/236x/31/0a/2f/310a2f69d0080782c9c01d57c7f02c9f.jpg
# Downloaded image 122: https://i.pinimg.com/236x/85/09/89/850989d4968c78173b1165953f23dc8a.jpg
# Downloaded image 123: https://i.pinimg.com/236x/9e/d9/7d/9ed97da3df8c533ce63c0f7c938818fe.jpg
# Downloaded image 124: https://i.pinimg.com/236x/95/cc/29/95cc291908f131af23092a30ac5c0879.jpg
# Downloaded image 125: https://i.pinimg.com/236x/28/0c/66/280c66cb9e614ad9fee054e6efa0921b.jpg
# Downloaded image 126: https://i.pinimg.com/236x/61/34/fc/6134fc24a88a7663f8dc1cfeae6ba0c0.jpg
# Downloaded image 127: https://i.pinimg.com/236x/5e/f3/62/5ef36241f08342136744ccc10d5387a6.jpg
# Downloaded image 128: https://i.pinimg.com/236x/fd/fd/69/fdfd69d5181a7209dd1ec06913f7c1a1.jpg
# Downloaded image 129: https://i.pinimg.com/236x/70/6a/4e/706a4e21f9a4a29d128b41c6d5d1e035.jpg
# Downloaded image 130: https://i.pinimg.com/236x/60/b3/75/60b375f1da5899b948a435defed4771e.jpg
# Downloaded image 131: https://i.pinimg.com/236x/86/ff/68/86ff6884404c843e9527806c95106dbf.jpg
# Downloaded image 132: https://i.pinimg.com/236x/66/0d/a2/660da2d446b255be435137c05574aabc.jpg
# Downloaded image 133: https://i.pinimg.com/236x/e1/3d/36/e13d36154f01fc6efd7a5b4d58b5172d.jpg
# Downloaded image 134: https://i.pinimg.com/236x/6d/71/c7/6d71c7e0d98f774d7c4d2b7e2eb226ae.jpg
# Downloaded image 135: https://i.pinimg.com/236x/00/5e/5e/005e5e45f0813aa4f2cd5051bffc5fc4.jpg
# Downloaded image 136: https://i.pinimg.com/236x/b2/9b/37/b29b371627d4a4b6c527b0cc2ad8b387.jpg
# Downloaded image 137: https://i.pinimg.com/236x/16/73/e7/1673e7bc634e8d5c0c2ad6db429efeb7.jpg
# Downloaded image 138: https://i.pinimg.com/236x/db/12/ee/db12ee7852f3a3794034a17dc0b13545.jpg
# Downloaded image 139: https://i.pinimg.com/236x/43/15/8b/43158b5b4b0b629e0d744e2f328ec871.jpg
# Downloaded image 140: https://i.pinimg.com/236x/04/8c/d8/048cd8f6067128c080d63c79cbfdcc72.jpg
# Downloaded image 141: https://i.pinimg.com/236x/fe/1d/0d/fe1d0df7d8892768dd27568bf4c587ad.jpg
# Downloaded image 142: https://i.pinimg.com/236x/ff/3e/7f/ff3e7f51578dba8e2aa2bf06f8929719.jpg
# Downloaded image 143: https://i.pinimg.com/236x/cd/60/c4/cd60c462830696fd6f1bee8ba737640b.jpg
# Downloaded image 144: https://i.pinimg.com/236x/16/29/24/162924a70c73945cb67d9c26abefd4a2.jpg
# Downloaded image 145: https://i.pinimg.com/236x/13/3a/e7/133ae7370074cb6daa4e783225b0bb3e.jpg
# Downloaded image 146: https://i.pinimg.com/236x/c3/3b/db/c33bdbc01c9edf1d9b461355dd63d2f9.jpg
# Downloaded image 147: https://i.pinimg.com/236x/b7/45/37/b74537ed5a0395e8ef0a1bc67d840da6.jpg
# Downloaded image 148: https://i.pinimg.com/236x/9f/e7/74/9fe7749b91d9e2cd2b7aaa21167067a0.jpg
# Downloaded image 149: https://i.pinimg.com/236x/bf/7e/b2/bf7eb21c0be3cd2bd41a75bd9502180d.jpg
# Downloaded image 150: https://i.pinimg.com/236x/8f/f5/f2/8ff5f274ff5809f8f8e2d1a1a0154e21.jpg
# Downloaded image 151: https://i.pinimg.com/236x/45/f0/b8/45f0b8a3912b18b64cd4138ed65b6bca.jpg
# Downloaded image 152: https://i.pinimg.com/236x/b7/4d/bb/b74dbb18b4af5d368adbea0875e7b1b6.jpg
# Downloaded image 153: https://i.pinimg.com/236x/bc/a3/52/bca352ab711266c9ba19898e3504b391.jpg
# Downloaded image 154: https://i.pinimg.com/236x/cd/c8/66/cdc8662ed78a6168d600d34e22ea2538.jpg
# Downloaded image 155: https://i.pinimg.com/236x/b8/89/38/b8893852752af97b4ca07fcf687bee36.jpg
# Downloaded image 156: https://i.pinimg.com/236x/8b/af/af/8bafaf4af4887c2654c65a525587c380.jpg
# Downloaded image 157: https://i.pinimg.com/236x/2e/b4/e2/2eb4e2320fc4d09e0774082971f73b0d.jpg
# Downloaded image 158: https://i.pinimg.com/236x/9d/97/ae/9d97ae972241e7432fce8fa45ee0dc02.jpg
# Downloaded image 159: https://i.pinimg.com/236x/e6/d3/b9/e6d3b905aa5319c344e45dbbfbad3790.jpg
# Downloaded image 160: https://i.pinimg.com/236x/30/44/ce/3044ce409c993c19a43aabfd85723dbd.jpg
# Downloaded image 161: https://i.pinimg.com/236x/ce/c9/b9/cec9b97fe4f26eed0caa6e70688e3fb2.jpg
# Downloaded image 162: https://i.pinimg.com/236x/06/38/1c/06381cfe785b9f7ed562b053448f7f7c.jpg
# Downloaded image 163: https://i.pinimg.com/236x/e1/ea/f9/e1eaf9d3f7d6b6dd1e00df3f37b75408.jpg
# Downloaded image 164: https://i.pinimg.com/236x/fa/1a/c1/fa1ac14249be6248398b75a019754a69.jpg
# Downloaded image 165: https://i.pinimg.com/236x/f8/da/f8/f8daf877c0b87b06d739715d8a0d8b85.jpg
# Downloaded image 166: https://i.pinimg.com/236x/30/db/74/30db74946ecad656a669886bd464fcf6.jpg
# Downloaded image 167: https://i.pinimg.com/236x/42/6e/67/426e672051a88daface6d84bd6317e4e.jpg
# Downloaded image 168: https://i.pinimg.com/236x/ea/4a/34/ea4a348569474b2af15a0b2b93fcee61.jpg
# Downloaded image 169: https://i.pinimg.com/236x/39/1b/13/391b13111b6e71931a278cf78be39b7d.jpg
# Downloaded image 170: https://i.pinimg.com/236x/26/dd/b5/26ddb52ce891cbc9425a48803ad14694.jpg
# Downloaded image 171: https://i.pinimg.com/236x/11/e2/cd/11e2cd25be7070cdc910824e6ed4fb4e.jpg
# Downloaded image 172: https://i.pinimg.com/236x/70/28/82/702882477d62e948ae11f3f73cce3a66.jpg
# Downloaded image 173: https://i.pinimg.com/236x/a7/f7/40/a7f7402700d9a035d86e009b3dff4d82.jpg
# Downloaded image 174: https://i.pinimg.com/236x/97/45/05/974505615859679d13825a52987cfcf1.jpg
# Downloaded image 175: https://i.pinimg.com/236x/42/2c/cf/422ccf0022ca04a54153b17c992124f1.jpg
# Downloaded image 176: https://i.pinimg.com/236x/05/c3/80/05c380bd2702d029f9f3b9278da7d538.jpg
# Downloaded image 177: https://i.pinimg.com/236x/b1/1f/18/b11f182656c73c2318af0fa50eebe928.jpg
# Downloaded image 178: https://i.pinimg.com/236x/bc/00/5f/bc005f0677f5935bfffebee0ae9dec1d.jpg
# Downloaded image 179: https://i.pinimg.com/236x/fe/56/94/fe56949f55354256f086c6844d0d30c6.jpg
# Downloaded image 180: https://i.pinimg.com/236x/2e/52/55/2e5255d53f3e03088074f741c136e6c3.jpg
# Downloaded image 181: https://i.pinimg.com/236x/67/21/37/672137bd6fea318ebb180a56ad4bd7cb.jpg
# Downloaded image 182: https://i.pinimg.com/236x/44/a0/98/44a09821b56f830f2facf2e2f10de661.jpg
# Downloaded image 183: https://i.pinimg.com/236x/e8/03/5d/e8035dc96a35982877b0827e3e9e9a2d.jpg
# Downloaded image 184: https://i.pinimg.com/236x/3d/9d/15/3d9d15a7f9693bd58a74da9a098bed98.jpg
# Downloaded image 185: https://i.pinimg.com/236x/8f/02/2c/8f022c97d6199d755694e7d2aa15bb37.jpg
# Downloaded image 186: https://i.pinimg.com/236x/6f/cb/2c/6fcb2cde7c7ce03f4eccfc4ce51888c6.jpg
# Downloaded image 187: https://i.pinimg.com/236x/db/5d/e6/db5de61d47a7349a1606c73749d8e017.jpg
# Downloaded image 188: https://i.pinimg.com/236x/82/15/a0/8215a012695246198dc5339abf28b364.jpg
# Downloaded image 189: https://i.pinimg.com/236x/92/97/11/929711c78363d2b91148b50502a36201.jpg
# Downloaded image 190: https://i.pinimg.com/236x/65/80/a4/6580a499aed741a8675162cce0ff0733.jpg
# Downloaded image 191: https://i.pinimg.com/236x/c8/7c/6e/c87c6e025b75ca2a1e5ae46f12a49e0d.jpg
# Downloaded image 192: https://i.pinimg.com/236x/66/7a/77/667a77b82b8d520df64e7a5500e42393.jpg
# Downloaded image 193: https://i.pinimg.com/236x/94/a1/a5/94a1a53e12900c1ace9ab0fa72333f0b.jpg
# Downloaded image 194: https://i.pinimg.com/236x/c7/b2/a6/c7b2a6b5384513b3ad20e39671dfe9e5.jpg
# Downloaded image 195: https://i.pinimg.com/236x/07/e6/59/07e659da6c5da857cfe589d3056d4dde.jpg
# Downloaded image 196: https://i.pinimg.com/236x/98/68/18/9868182cd666d907c23c86d80600126e.jpg
# Downloaded image 197: https://i.pinimg.com/236x/9b/e7/6f/9be76fa8f5f881c5d2fb99bab4ac11c6.jpg
# Downloaded image 198: https://i.pinimg.com/236x/3e/49/81/3e49814ede366261c605c27942f5b8be.jpg
# Downloaded image 199: https://i.pinimg.com/236x/46/69/e7/4669e7d149aa3574bd4baf7fc2fdad35.jpg
# Downloaded image 200: https://i.pinimg.com/236x/54/ca/3f/54ca3f3fb6d06eaa79dc09e16ee6f0c5.jpg
# Downloaded image 201: https://i.pinimg.com/236x/54/e4/4c/54e44cc548dba023d0d429a1fed67f59.jpg
# Downloaded image 202: https://i.pinimg.com/236x/71/ef/0d/71ef0dabb1cab6fc739aad7227cdff64.jpg
# Downloaded image 203: https://i.pinimg.com/236x/f9/4e/b8/f94eb86912f417f680785321f7ff26ab.jpg
